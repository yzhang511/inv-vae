# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline

import random
seed = 666
random.seed(seed)

from sklearn.decomposition import PCA

import torch
from torch import optim
import torch.utils.data as utils
from torchvision import datasets
torch.manual_seed(seed)

from inv_vae.utils.simulate import simulate_networks
from inv_vae.utils.helpers import Namespace, reset_weights
from inv_vae.models.vae import VAE
from inv_vae.models.inv_vae import INV_VAE

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
# Out:
# cuda:0

# %%
SMALL_SIZE = 10
MEDIUM_SIZE = 15
BIGGER_SIZE = 20

plt.rc('font', size=MEDIUM_SIZE)         
plt.rc('axes', titlesize=MEDIUM_SIZE)     
plt.rc('axes', labelsize=MEDIUM_SIZE) 
plt.rc('axes', linewidth = 3)
plt.rc('xtick', labelsize=MEDIUM_SIZE)   
plt.rc('ytick', labelsize=MEDIUM_SIZE)   
plt.rc('legend', fontsize=MEDIUM_SIZE)   
plt.rc('figure', titlesize=MEDIUM_SIZE)

# %% [markdown]
# simulate data

# %%
n_nets = 1000
n_nodes = 68
p_in = .25
p_out = .01
n_noisy_nets = int(n_nets*.2)
noise_level = .6
noise_sd = .05

# %%
sim_nets, noisy_nets, noises, noise_ids = simulate_networks(n_nets=n_nets, n_nodes=n_nodes, p_in=p_in, p_out=p_out, seed=seed,
                                          n_noisy_nets=n_noisy_nets, noise_level=noise_level, noise_sd=noise_sd)
print(sim_nets.shape, noisy_nets.shape, noises.shape)
# Out:
# (1000, 68, 68) (1000, 68, 68) (1000,)

# %%
config = Namespace(n_nodes=68, latent_dim=68, hidden_dim=1024, nuisance_dim=0,
    n_enc_layers=1, n_dec_layers=5, n_neighbors=32, drop_out=0.,
    beta = .1, add_reg = False, y_dim = 0, 
    batch_size=32, n_epochs=200, lr=3e-6, device=DEVICE)

# %%
A_mat = np.mean(noisy_nets, axis=0)
A_mat = A_mat + A_mat.transpose()
knn_masks = [torch.from_numpy(np.argsort(np.argsort(A_mat, axis=-1), axis=-1) < config.n_neighbors+i).float().to(config.device) for i in range(config.n_dec_layers)]

# %%
big_sim_nets = sim_nets[np.arange(n_noisy_nets)]
small_sim_nets = sim_nets[np.arange(n_noisy_nets, n_nets)]
diff_sim_nets = small_sim_nets.mean(0) - big_sim_nets.mean(0)

big_noise_nets = noisy_nets[np.arange(n_noisy_nets)]
small_noise_nets = noisy_nets[np.arange(n_noisy_nets, n_nets)]
diff_noise_nets = small_noise_nets.mean(0) - big_noise_nets.mean(0)

# %%
pca = PCA(2)
sim_Xt = pca.fit_transform(sim_nets.reshape(-1, n_nodes*n_nodes))
noisy_Xt = pca.fit_transform(noisy_nets.reshape(-1, n_nodes*n_nodes))
sim_df = pd.DataFrame({"pc1": sim_Xt[:,0], "pc2": sim_Xt[:,1], "noise": noises})
noisy_df = pd.DataFrame({"pc1": noisy_Xt[:,0], "pc2": noisy_Xt[:,1], "noise": noises})

# %% [markdown]
# prepare datasets for training

# %%
ids = list(range(n_nets))
random.shuffle(ids)
train_ids = ids[:int(.9*n_nets)]
val_ids = ids[int(.9*n_nets):]
print(len(train_ids), len(val_ids))
tensor_nets = torch.stack([torch.Tensor(i) for i in list(noisy_nets)]).to(torch.float32).view(-1, config.n_nodes*config.n_nodes)
tensor_noises = torch.from_numpy(noises).to(torch.float32).view(-1, 1)

train_set = utils.TensorDataset(tensor_nets[train_ids], 
                        tensor_noises[train_ids] )
val_set = utils.TensorDataset(tensor_nets[val_ids], 
                        tensor_noises[val_ids] )

train_loader = utils.DataLoader(train_set, config.batch_size) 
val_loader = utils.DataLoader(val_set, config.batch_size)
# Out:
# 900 100

# %% [markdown]
# vae

# %%
model = VAE(config).to(config.device)
model.apply(reset_weights)
model.set_mask(knn_masks)
optimizer = optim.Adam(model.parameters(), lr=config.lr)

# %%
train_losses = []
val_losses = []
for epoch in range(config.n_epochs):
    train_loss = model.custom_train(epoch, train_loader, model, optimizer, config.device, n_epoch_display=5)
    val_loss = model.custom_test(epoch, val_loader, model, config.device, n_epoch_display=5)
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
train_losses = np.array(train_losses)
val_losses = np.array(val_losses)
# Out:
# epoch: 0 train loss: 5461.124 nll: 5460.351 kl: 7.726
# epoch: 0 test loss 4654.860 nll: 4653.928 kl: 9.318
# epoch: 5 train loss: 2932.139 nll: 2931.387 kl: 7.519
# epoch: 5 test loss 2938.180 nll: 2937.411 kl: 7.680
# epoch: 10 train loss: 2766.133 nll: 2764.329 kl: 18.034
# epoch: 10 test loss 2795.018 nll: 2793.302 kl: 17.162
# epoch: 15 train loss: 2731.535 nll: 2729.589 kl: 19.467
# epoch: 15 test loss 2760.695 nll: 2758.890 kl: 18.042
# epoch: 20 train loss: 2720.188 nll: 2718.079 kl: 21.090
# epoch: 20 test loss 2748.049 nll: 2746.083 kl: 19.662
# epoch: 25 train loss: 2714.902 nll: 2712.426 kl: 24.764
# epoch: 25 test loss 2742.044 nll: 2739.708 kl: 23.354
# epoch: 30 train loss: 2711.322 nll: 2708.266 kl: 30.558
# epoch: 30 test loss 2739.216 nll: 2736.355 kl: 28.615
# epoch: 35 train loss: 2708.538 nll: 2704.788 kl: 37.503
# epoch: 35 test loss 2734.820 nll: 2731.334 kl: 34.866
# epoch: 40 train loss: 2705.459 nll: 2701.034 kl: 44.246
# epoch: 40 test loss 2731.678 nll: 2727.590 kl: 40.876
# epoch: 45 train loss: 2702.199 nll: 2697.034 kl: 51.651
# epoch: 45 test loss 2728.856 nll: 2724.094 kl: 47.616
# epoch: 50 train loss: 2698.507 nll: 2692.623 kl: 58.845
# epoch: 50 test loss 2724.639 nll: 2719.262 kl: 53.766
# epoch: 55 train loss: 2694.396 nll: 2687.834 kl: 65.629
# epoch: 55 test loss 2720.777 nll: 2714.816 kl: 59.603
# epoch: 60 train loss: 2690.187 nll: 2682.947 kl: 72.398
# epoch: 60 test loss 2718.392 nll: 2711.842 kl: 65.506
# epoch: 65 train loss: 2685.343 nll: 2677.513 kl: 78.301
# epoch: 65 test loss 2712.962 nll: 2705.905 kl: 70.568
# epoch: 70 train loss: 2680.921 nll: 2672.461 kl: 84.595
# epoch: 70 test loss 2708.811 nll: 2701.241 kl: 75.701
# epoch: 75 train loss: 2675.924 nll: 2666.870 kl: 90.544
# epoch: 75 test loss 2704.574 nll: 2696.538 kl: 80.360
# epoch: 80 train loss: 2670.456 nll: 2660.877 kl: 95.790
# epoch: 80 test loss 2700.163 nll: 2691.719 kl: 84.447
# epoch: 85 train loss: 2664.273 nll: 2654.310 kl: 99.627
# epoch: 85 test loss 2698.425 nll: 2689.726 kl: 86.996
# epoch: 90 train loss: 2657.546 nll: 2647.104 kl: 104.423
# epoch: 90 test loss 2689.105 nll: 2680.108 kl: 89.963
# epoch: 95 train loss: 2651.750 nll: 2640.884 kl: 108.651
# epoch: 95 test loss 2687.981 nll: 2678.651 kl: 93.296
# epoch: 100 train loss: 2644.626 nll: 2633.389 kl: 112.377
# epoch: 100 test loss 2683.215 nll: 2673.773 kl: 94.426
# epoch: 105 train loss: 2636.965 nll: 2625.319 kl: 116.465
# epoch: 105 test loss 2681.752 nll: 2672.069 kl: 96.838
# epoch: 110 train loss: 2631.411 nll: 2619.505 kl: 119.052
# epoch: 110 test loss 2674.841 nll: 2664.997 kl: 98.447
# epoch: 115 train loss: 2623.535 nll: 2611.261 kl: 122.743
# epoch: 115 test loss 2670.919 nll: 2660.927 kl: 99.913
# epoch: 120 train loss: 2616.439 nll: 2603.868 kl: 125.711
# epoch: 120 test loss 2667.939 nll: 2657.812 kl: 101.271
# epoch: 125 train loss: 2610.255 nll: 2597.363 kl: 128.914
# epoch: 125 test loss 2663.405 nll: 2653.222 kl: 101.837
# epoch: 130 train loss: 2602.377 nll: 2589.343 kl: 130.342
# epoch: 130 test loss 2662.243 nll: 2652.086 kl: 101.566
# epoch: 135 train loss: 2595.197 nll: 2581.952 kl: 132.449
# epoch: 135 test loss 2657.682 nll: 2647.518 kl: 101.644
# epoch: 140 train loss: 2588.628 nll: 2575.166 kl: 134.620
# epoch: 140 test loss 2655.902 nll: 2645.684 kl: 102.186
# epoch: 145 train loss: 2580.904 nll: 2567.149 kl: 137.552
# epoch: 145 test loss 2648.930 nll: 2638.567 kl: 103.634
# epoch: 150 train loss: 2573.598 nll: 2559.729 kl: 138.693
# epoch: 150 test loss 2650.545 nll: 2640.306 kl: 102.389
# epoch: 155 train loss: 2567.458 nll: 2553.457 kl: 140.013
# epoch: 155 test loss 2649.455 nll: 2639.218 kl: 102.374
# epoch: 160 train loss: 2561.277 nll: 2547.188 kl: 140.891
# epoch: 160 test loss 2652.041 nll: 2641.883 kl: 101.584
# epoch: 165 train loss: 2555.720 nll: 2541.553 kl: 141.667
# epoch: 165 test loss 2647.418 nll: 2637.403 kl: 100.147
# epoch: 170 train loss: 2549.739 nll: 2535.540 kl: 141.982
# epoch: 170 test loss 2646.356 nll: 2636.354 kl: 100.019
# epoch: 175 train loss: 2543.449 nll: 2529.192 kl: 142.576
# epoch: 175 test loss 2649.392 nll: 2639.446 kl: 99.465
# epoch: 180 train loss: 2538.343 nll: 2524.037 kl: 143.055
# epoch: 180 test loss 2650.442 nll: 2640.631 kl: 98.115
# epoch: 185 train loss: 2533.685 nll: 2519.407 kl: 142.785
# epoch: 185 test loss 2656.245 nll: 2646.556 kl: 96.882
# epoch: 190 train loss: 2528.070 nll: 2513.881 kl: 141.898
# epoch: 190 test loss 2653.479 nll: 2643.883 kl: 95.963
# epoch: 195 train loss: 2524.531 nll: 2510.363 kl: 141.684
# epoch: 195 test loss 2651.829 nll: 2642.378 kl: 94.514

# %%
# diagnostics
fig, axes = plt.subplots(1, 3, figsize=(15, 3))
axes[0].plot(train_losses[:,0], linewidth=2, label='train')
axes[0].plot(val_losses[:,0], linewidth=2, label='val')
axes[0].set_title('loss')
axes[0].legend(loc=1)

axes[1].plot(train_losses[:,1], linewidth=2, label='train')
axes[1].plot(val_losses[:,1], linewidth=2, label='val')
axes[1].set_title('nll')
axes[1].legend(loc=1)

axes[2].plot(train_losses[:,2], linewidth=2, label='train')
axes[2].plot(val_losses[:,2], linewidth=2, label='val')
axes[2].set_title('kl')
axes[2].legend(loc=1)
plt.tight_layout()
plt.show()

# %%
z_mean, z_logvar = model.encode(tensor_nets.to(torch.float32).view(-1, config.n_nodes*config.n_nodes).to(config.device))
z_sample = model.reparameterize(z_mean, z_logvar)
vae_latents = z_sample.detach().cpu().numpy()
x_recon = model.decode(z_sample).detach().cpu().numpy().reshape(-1, config.n_nodes, config.n_nodes)

# %%
big_noise_recon = x_recon[np.arange(n_noisy_nets)]
small_noise_recon = x_recon[np.arange(n_noisy_nets, n_nets)]
diff_noise_recon= small_noise_recon.mean(0) - big_noise_recon.mean(0)

# %%
pca = PCA(2)
vae_Xt = pca.fit_transform(vae_latents)
vae_df = pd.DataFrame({"pc1": vae_Xt[:,0], "pc2": vae_Xt[:,1], "noise": noises})

# %% [markdown]
# inv-vae

# %%
config = Namespace(n_nodes=68, latent_dim=68, hidden_dim=1024, nuisance_dim=1,
    n_enc_layers=1, n_dec_layers=5, n_neighbors=32, drop_out=0.,
    beta = 1., gamma = .1, add_reg = False, y_dim = 0,               
    batch_size=32, n_epochs=200, lr=3e-6, device=DEVICE)

# %%
inv_model = INV_VAE(config).to(config.device)
inv_model.apply(reset_weights)
inv_model.set_mask(knn_masks)
optimizer = optim.Adam(inv_model.parameters(), lr=config.lr)

# %%
train_losses = []
val_losses = []
for epoch in range(config.n_epochs):
    train_loss = inv_model.custom_train(epoch, train_loader, inv_model, optimizer, config.device, n_epoch_display=5)
    val_loss = inv_model.custom_test(epoch, val_loader, inv_model, config.device, n_epoch_display=5)
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
train_losses = np.array(train_losses)
val_losses = np.array(val_losses)
# Out:
# epoch: 0 train loss: 3030.777 nll: 5500.941 kl: 5.245 inv_loss: 0.142
# epoch: 0 test loss 2585.439 nll: 4693.902 kl: 3.778 inv_loss: 0.149
# epoch: 5 train loss: 1621.742 nll: 2945.906 kl: 1.485 inv_loss: 0.081
# epoch: 5 test loss 1624.272 nll: 2950.673 kl: 1.392 inv_loss: 0.091
# epoch: 10 train loss: 1526.773 nll: 2774.182 kl: 0.968 inv_loss: 0.054
# epoch: 10 test loss 1542.316 nll: 2802.489 kl: 0.941 inv_loss: 0.063
# epoch: 15 train loss: 1506.020 nll: 2736.993 kl: 0.670 inv_loss: 0.038
# epoch: 15 test loss 1521.783 nll: 2765.654 kl: 0.668 inv_loss: 0.045
# epoch: 20 train loss: 1499.150 nll: 2724.850 kl: 0.480 inv_loss: 0.027
# epoch: 20 test loss 1514.539 nll: 2752.812 kl: 0.489 inv_loss: 0.033
# epoch: 25 train loss: 1496.424 nll: 2720.147 kl: 0.341 inv_loss: 0.019
# epoch: 25 test loss 1511.397 nll: 2747.344 kl: 0.355 inv_loss: 0.024
# epoch: 30 train loss: 1495.140 nll: 2717.994 kl: 0.242 inv_loss: 0.013
# epoch: 30 test loss 1509.969 nll: 2744.926 kl: 0.258 inv_loss: 0.017
# epoch: 35 train loss: 1494.474 nll: 2716.916 kl: 0.169 inv_loss: 0.009
# epoch: 35 test loss 1509.100 nll: 2743.481 kl: 0.184 inv_loss: 0.012
# epoch: 40 train loss: 1494.112 nll: 2716.358 kl: 0.115 inv_loss: 0.006
# epoch: 40 test loss 1508.616 nll: 2742.700 kl: 0.130 inv_loss: 0.008
# epoch: 45 train loss: 1493.839 nll: 2715.915 kl: 0.085 inv_loss: 0.004
# epoch: 45 test loss 1508.487 nll: 2742.520 kl: 0.101 inv_loss: 0.006
# epoch: 50 train loss: 1493.731 nll: 2715.740 kl: 0.073 inv_loss: 0.004
# epoch: 50 test loss 1508.277 nll: 2742.160 kl: 0.089 inv_loss: 0.005
# epoch: 55 train loss: 1493.593 nll: 2715.499 kl: 0.068 inv_loss: 0.003
# epoch: 55 test loss 1508.326 nll: 2742.258 kl: 0.083 inv_loss: 0.005
# epoch: 60 train loss: 1493.544 nll: 2715.412 kl: 0.067 inv_loss: 0.003
# epoch: 60 test loss 1508.025 nll: 2741.714 kl: 0.081 inv_loss: 0.005
# epoch: 65 train loss: 1493.507 nll: 2715.343 kl: 0.067 inv_loss: 0.003
# epoch: 65 test loss 1507.960 nll: 2741.597 kl: 0.081 inv_loss: 0.005
# epoch: 70 train loss: 1493.422 nll: 2715.186 kl: 0.069 inv_loss: 0.003
# epoch: 70 test loss 1508.078 nll: 2741.810 kl: 0.082 inv_loss: 0.005
# epoch: 75 train loss: 1493.369 nll: 2715.084 kl: 0.073 inv_loss: 0.003
# epoch: 75 test loss 1507.871 nll: 2741.429 kl: 0.085 inv_loss: 0.005
# epoch: 80 train loss: 1493.344 nll: 2715.032 kl: 0.076 inv_loss: 0.004
# epoch: 80 test loss 1507.827 nll: 2741.343 kl: 0.087 inv_loss: 0.005
# epoch: 85 train loss: 1493.383 nll: 2715.095 kl: 0.081 inv_loss: 0.004
# epoch: 85 test loss 1507.762 nll: 2741.218 kl: 0.091 inv_loss: 0.005
# epoch: 90 train loss: 1493.289 nll: 2714.913 kl: 0.086 inv_loss: 0.004
# epoch: 90 test loss 1507.868 nll: 2741.405 kl: 0.095 inv_loss: 0.005
# epoch: 95 train loss: 1493.242 nll: 2714.818 kl: 0.092 inv_loss: 0.004
# epoch: 95 test loss 1507.846 nll: 2741.359 kl: 0.098 inv_loss: 0.005
# epoch: 100 train loss: 1493.295 nll: 2714.903 kl: 0.098 inv_loss: 0.005
# epoch: 100 test loss 1507.795 nll: 2741.260 kl: 0.102 inv_loss: 0.006
# epoch: 105 train loss: 1493.256 nll: 2714.814 kl: 0.108 inv_loss: 0.005
# epoch: 105 test loss 1507.656 nll: 2740.995 kl: 0.109 inv_loss: 0.006
# epoch: 110 train loss: 1493.198 nll: 2714.692 kl: 0.117 inv_loss: 0.005
# epoch: 110 test loss 1507.668 nll: 2741.007 kl: 0.114 inv_loss: 0.006
# epoch: 115 train loss: 1493.195 nll: 2714.666 kl: 0.128 inv_loss: 0.006
# epoch: 115 test loss 1507.634 nll: 2740.933 kl: 0.120 inv_loss: 0.006
# epoch: 120 train loss: 1493.116 nll: 2714.499 kl: 0.140 inv_loss: 0.006
# epoch: 120 test loss 1507.728 nll: 2741.091 kl: 0.127 inv_loss: 0.007
# epoch: 125 train loss: 1493.129 nll: 2714.499 kl: 0.154 inv_loss: 0.007
# epoch: 125 test loss 1507.828 nll: 2741.259 kl: 0.134 inv_loss: 0.007
# epoch: 130 train loss: 1493.110 nll: 2714.438 kl: 0.169 inv_loss: 0.008
# epoch: 130 test loss 1507.402 nll: 2740.472 kl: 0.141 inv_loss: 0.007
# epoch: 135 train loss: 1493.008 nll: 2714.221 kl: 0.185 inv_loss: 0.009
# epoch: 135 test loss 1507.423 nll: 2740.495 kl: 0.150 inv_loss: 0.008
# epoch: 140 train loss: 1493.100 nll: 2714.354 kl: 0.205 inv_loss: 0.010
# epoch: 140 test loss 1507.304 nll: 2740.261 kl: 0.160 inv_loss: 0.008
# epoch: 145 train loss: 1492.899 nll: 2713.946 kl: 0.227 inv_loss: 0.011
# epoch: 145 test loss 1507.462 nll: 2740.526 kl: 0.172 inv_loss: 0.009
# epoch: 150 train loss: 1492.978 nll: 2714.045 kl: 0.252 inv_loss: 0.012
# epoch: 150 test loss 1507.356 nll: 2740.311 kl: 0.184 inv_loss: 0.009
# epoch: 155 train loss: 1492.851 nll: 2713.762 kl: 0.281 inv_loss: 0.013
# epoch: 155 test loss 1507.271 nll: 2740.140 kl: 0.193 inv_loss: 0.010
# epoch: 160 train loss: 1492.859 nll: 2713.713 kl: 0.315 inv_loss: 0.015
# epoch: 160 test loss 1507.385 nll: 2740.316 kl: 0.210 inv_loss: 0.011
# epoch: 165 train loss: 1492.630 nll: 2713.225 kl: 0.354 inv_loss: 0.017
# epoch: 165 test loss 1507.222 nll: 2739.997 kl: 0.222 inv_loss: 0.012
# epoch: 170 train loss: 1492.505 nll: 2712.912 kl: 0.401 inv_loss: 0.019
# epoch: 170 test loss 1507.344 nll: 2740.187 kl: 0.240 inv_loss: 0.013
# epoch: 175 train loss: 1492.378 nll: 2712.584 kl: 0.455 inv_loss: 0.022
# epoch: 175 test loss 1507.810 nll: 2740.993 kl: 0.263 inv_loss: 0.014
# epoch: 180 train loss: 1492.405 nll: 2712.505 kl: 0.524 inv_loss: 0.025
# epoch: 180 test loss 1507.397 nll: 2740.202 kl: 0.285 inv_loss: 0.015
# epoch: 185 train loss: 1492.190 nll: 2711.976 kl: 0.600 inv_loss: 0.029
# epoch: 185 test loss 1507.271 nll: 2739.934 kl: 0.306 inv_loss: 0.017
# epoch: 190 train loss: 1491.868 nll: 2711.227 kl: 0.689 inv_loss: 0.034
# epoch: 190 test loss 1507.207 nll: 2739.761 kl: 0.336 inv_loss: 0.018
# epoch: 195 train loss: 1491.764 nll: 2710.841 kl: 0.797 inv_loss: 0.039
# epoch: 195 test loss 1506.858 nll: 2739.063 kl: 0.371 inv_loss: 0.020

# %%
# diagnostics
fig, axes = plt.subplots(1, 4, figsize=(18, 3))
axes[0].plot(train_losses[:,0], linewidth=2, label='train')
axes[0].plot(val_losses[:,0], linewidth=2, label='val')
axes[0].set_title('loss')
axes[0].legend(loc=1)

axes[1].plot(train_losses[:,1], linewidth=2, label='train')
axes[1].plot(val_losses[:,1], linewidth=2, label='val')
axes[1].set_title('nll')
axes[1].legend(loc=1)

axes[2].plot(train_losses[:,2], linewidth=2, label='train')
axes[2].plot(val_losses[:,2], linewidth=2, label='val')
axes[2].set_title('kl')
axes[2].legend(loc=1)

axes[3].plot(train_losses[:,3], linewidth=2, label='train')
axes[3].plot(val_losses[:,3], linewidth=2, label='val')
axes[3].set_title('inv_loss')
axes[3].legend(loc=1)
plt.tight_layout()
plt.show()

# %%
z_mean, z_logvar = inv_model.encode(tensor_nets.to(config.device))
z_sample = inv_model.reparameterize(z_mean, z_logvar)
inv_latents = z_sample.detach().cpu().numpy()
x_denoised = inv_model.decode(z_sample, 
                      torch.ones_like(tensor_noises).to(config.device) 
                      ).detach().cpu().numpy().reshape(-1, config.n_nodes, config.n_nodes)

# %%
big_noise_denoised = x_denoised[np.arange(n_noisy_nets)]
small_noise_denoised = x_denoised[np.arange(n_noisy_nets, n_nets)]
diff_noise_denoised = small_noise_denoised.mean(0) - big_noise_denoised.mean(0)

# %%
pca = PCA(2)
inv_vae_Xt = pca.fit_transform(inv_latents)
inv_vae_df = pd.DataFrame({"pc1": inv_vae_Xt[:,0], "pc2": inv_vae_Xt[:,1], "noise": noises})

# %% [markdown]
# plotting

# %%
fig, axes = plt.subplots(3, 4, figsize=(15, 8))

p1 = axes[0,0].imshow(sim_nets.mean(0), aspect='auto', cmap='Blues', vmin=0, vmax=2)
axes[0,0].set_title('noise-free')
cbar = plt.colorbar(p1, ax=axes[0,0])

p2 = axes[1,0].imshow(diff_sim_nets, aspect='auto', cmap='binary', vmin=0, vmax=2)
cbar = plt.colorbar(p2, ax=axes[1,0])

p3 = axes[2,0].scatter(x="pc1", y="pc2", c="noise", cmap='coolwarm_r', data=sim_df, s=3, alpha=0.5)
axes[2,0].set_xlabel('pc1')
axes[2,0].set_ylabel('pc2')
axes[2,0].spines['top'].set_visible(False)
axes[2,0].spines['right'].set_visible(False)
cbar = plt.colorbar(p3, ax=axes[2,0], label="noise")

p4 = axes[0,1].imshow(noisy_nets.mean(0), aspect='auto', cmap='Blues', vmin=0, vmax=2)
axes[0,1].set_title('noise-affected')
cbar = plt.colorbar(p4, ax=axes[0,1])

p5 = axes[1,1].imshow(diff_noise_nets, aspect='auto', cmap='binary', vmin=0, vmax=2)
cbar = plt.colorbar(p5, ax=axes[1,1])

p6 = axes[2,1].scatter(x="pc1", y="pc2", c="noise", cmap='coolwarm_r', data=noisy_df, s=3, alpha=0.5)
axes[2,1].set_xlabel('pc1')
axes[2,1].spines['top'].set_visible(False)
axes[2,1].spines['right'].set_visible(False)
cbar = plt.colorbar(p6, ax=axes[2,1], label="noise")

p7 = axes[0,2].imshow(x_recon.mean(0), aspect='auto', cmap='Blues', vmin=0, vmax=2)
axes[0,2].set_title('GATE')
cbar = plt.colorbar(p7, ax=axes[0,2])

p8 = axes[1,2].imshow(diff_noise_recon, aspect='auto', cmap='binary', vmin=0, vmax=2)
cbar = plt.colorbar(p8, ax=axes[1,2])

p9 = axes[2,2].scatter(x="pc1", y="pc2", c="noise", cmap='coolwarm_r', data=vae_df, s=3, alpha=0.5)
axes[2,2].set_xlabel('pc1')
axes[2,2].spines['top'].set_visible(False)
axes[2,2].spines['right'].set_visible(False)
cbar = plt.colorbar(p9, ax=axes[2,2], label="noise")

p10 = axes[0,3].imshow(x_denoised.mean(0), aspect='auto', cmap='Blues', vmin=0, vmax=2)
axes[0,3].set_title('inv-VAE')
cbar = plt.colorbar(p10, ax=axes[0,3])

p11 = axes[1,3].imshow(diff_noise_denoised, aspect='auto', cmap='binary', vmin=0, vmax=2)
cbar = plt.colorbar(p11, ax=axes[1,3])

p12 = axes[2,3].scatter(x="pc1", y="pc2", c="noise", cmap='coolwarm_r', data=inv_vae_df, s=3, alpha=0.5)
axes[2,3].set_xlabel('pc1')
axes[2,3].spines['top'].set_visible(False)
axes[2,3].spines['right'].set_visible(False)
cbar = plt.colorbar(p12, ax=axes[2,3], label="noise")

plt.tight_layout()
plt.savefig('saved_figs/fig3_simulation.png', facecolor='white', dpi=800)
